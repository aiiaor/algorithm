# %% [markdown]
# Shortest Distance Query

# %% [markdown]
# For more information about the project, please refer to the [project specification](https://cgi.cse.unsw.edu.au/~cs9312/24T2/project/). You can edit this file and add anything you like. We will only use the code cell of the `ShortestDistanceQuery` class for testing. You can add descriptions and some theoretical analysis (e.g. index space, query time complexity, and index time complexity) to this file without creating a separate PDF document.
#
# **Note**: Make sure to **sequentially run all cells in each section** in order to carry over intermediate variables/packages to the next cell.

# %% [markdown]
# ## 1. Code Template
# You need to implement the `ShortestDistanceQuery` class to support shortest distance queries for large graphs (e.g. hundreds of millions of vertices and edges). A code template is given below.
#
# The `ShortestDistanceQuery` class is initialized by a graph `G`. The data structure of `G` will be presented in the next section. The class calls the function `preprocess` to precompute some index structure for `G`. The `query` function has two inputs: `vertex_u` and `vertex_v`. The function outputs the shortest distance between `vertex_u` and `vertex_v` in `G`.

# %%
################################################################################
# You can import any Python Standard Library modules~
from collections import deque
import copy
import numpy as np
from tqdm import tqdm
################################################################################

class ShortestDistanceQuery(object):
    def __init__(self, G):
        self.G = G

        self.adj_list = G.adj_list

        self.L = [set() for _ in range(G.vertex_num)]
        self.L_dist = [{} for _ in range(G.vertex_num)]

        self.processed = np.zeros(G.vertex_num, dtype=bool)

        # Calculate degree of each vertex
        self.degrees = np.array([len(self.adj_list[v]) for v in range(G.vertex_num)])

        self.preprocess(G)

    def preprocess(self, G):
        
        #sort the vertices by degree
        vertices = np.argsort(-self.degrees)


        for u in tqdm(vertices):
            visited = np.copy(self.processed)

            self.L[u].add(u)
            self.L_dist[u][u] = 0
            queue = deque()

            queue.append((u,0))

            #BFS
            while queue:
                (curr_u,dist_u) = queue.popleft()
                visited[curr_u] = True
                for w in self.adj_list[curr_u]:
                    if visited[w]:
                        continue
                    if w not in self.L_dist[u] or self.L_dist[u][w] > dist_u + 1:
                        self.L[w].add(u)
                        self.L_dist[w][u] = dist_u+1
                        self.L[u].add(w)
                        self.L_dist[u][w] = dist_u+1
                    queue.append((w,dist_u+1))

            self.processed[u] = True   
        
        return
    
    
    def query(self, vertex_u, vertex_v):
        shortest_distance = 0

        if vertex_u == vertex_v:
            return 0
        
        if vertex_v in self.adj_list[vertex_u]:
            return 1
        
        intersect_value = self.intersect(self.L[vertex_u],self.L[vertex_v])
        
        if len(intersect_value) == 0:
            return -1
        
        for u in intersect_value:
            dist = self.L_dist[vertex_u][u] + self.L_dist[u][vertex_v]
            if shortest_distance == 0 or dist < shortest_distance:
                #print(f"Update shortest_distance: {dist} with u: {u}")
                shortest_distance = dist
        
        return shortest_distance

    def intersect(self,L1,L2):
        return set(L1) & set(L2)

# %% [markdown]
# ## 2. Graph Data Structure
# The following is the data stucture of the input graph `G`.

# %%
class UndirectedUnweightedGraph(object):
    def __init__(self, edge_list):
        self.adj_list = []
        self.vertex_num = 0
        self.edge_num = 0
        info = True
        for [vertex_u, vertex_v] in edge_list:
            if info:
                info = False
                self.vertex_num = vertex_u
                self.edge_num = vertex_v
                self.adj_list = [list() for _ in range(self.vertex_num)]
            else:
                self.adj_list[vertex_u].append(vertex_v)
                self.adj_list[vertex_v].append(vertex_u)

# %% [markdown]
# ## 3. How to test your code

# %% [markdown]
# ### 3.1 Download the sample dataset.
#
# Running the following command will create the **COMP9312-24T2-Project** folder, which contains the files for the three datasets.
#
# > **Cora** (2k vertices) is a real citation graph, **map_BJ_part** (4k vertices) is a real road network for a small area of Beijing, and **map_NY_part** (7k vertices) is a real road network for a small area of New York. For the two road networks, we erase the weight of each edge in the original dataset to generate unweighted graphs for simplicity.
#
# There are three files for each dataset, where ***.graph** includes the graph information and all graph edges (vertex IDs are consecutive and start from 0), ***.query** includes a set of queries for testing. ***.answer** includes the correct answer to each query for your reference.
#
# If the dataset already exists, an error like "*destination path 'COMP9312-24T2-Project' already exists*" will appear.
#
# **NOTE**: We will test the code using different datasets.

# %%
# !git clone https://github.com/kevinChnn/COMP9312-24T2-Project

# %% [markdown]
# ### 3.2 The main function
#
# Our test procedure first loads the graph dataset and the query dataset. Then, it calls the `ShortestDistanceQuery` class to preprocess the graph. After that, it will run each query and test its efficiency and correctness.

# %%
import time
import numpy as np

if __name__ == "__main__":

    print('\n######## Loading the dataset...')
    # edge_list = np.loadtxt('./sample_test.graph', dtype=int)
    # query_list = np.loadtxt('./sample_test-sd.query', dtype=int)
    # edge_list = np.loadtxt('./COMP9312-24T2-Project/cora.graph', dtype=int)
    # query_list = np.loadtxt('./COMP9312-24T2-Project/cora-sd.query', dtype=int)
    edge_list = np.loadtxt('./COMP9312-24T2-Project/map_BJ_part.graph', dtype=int)
    query_list = np.loadtxt('./COMP9312-24T2-Project/map_BJ_part-sd.query', dtype=int)
    # edge_list = np.loadtxt('./COMP9312-24T2-Project/map_NY_part.graph', dtype=int)
    # query_list = np.loadtxt('./COMP9312-24T2-Project/map_NY_part-sd.query', dtype=int)
    G = UndirectedUnweightedGraph(edge_list)
    print("Number of vertices:", G.vertex_num)
    print("Number of edges:", G.edge_num)
    print("Edge list:", G.adj_list)

    print('\n######## Preprocessing the graph...')
    start_preprocessing = time.time()
    SDQ = ShortestDistanceQuery(G)
    end_preprocessing = time.time()
    print("Preprocessing time: {:.8f}".format(end_preprocessing-start_preprocessing))

    print('\n######## Query Testing...')
    start_query = time.time()
    count_false = 0
    for i in range(query_list.shape[0]):
        distance = SDQ.query(query_list[i][0], query_list[i][1])
        print("The shortest distance between {} and {} is: (output = {}, expected = {}) {}".format(query_list[i][0], query_list[i][1],distance, query_list[i][2], query_list[i][2]==distance))
        if query_list[i][2]!=distance:
            print("FOUND FALSE! The shortest distance between {} and {} is: (output = {}, expected = {})".format(query_list[i][0], query_list[i][1],distance, query_list[i][2]))
            count_false += 1
            break
    end_query = time.time()
    print("Count of false outputs:", count_false)
    print("Average query time: {:.8f}".format((end_query-start_query)/query_list.shape[0]))
# Out:
# ######## Loading the dataset...
# Number of vertices: 4021
# Number of edges: 4812
# Edge list: [[1, 2], [0, 692, 1176, 2773], [0, 1782], [4, 5, 6], [3, 1432, 1895], [3, 6, 2498, 2499], [3, 5, 1948, 2766], [8, 9], [7, 362, 687, 3285], [7, 352, 353], [11, 12, 13, 14, 15], [10, 12, 678, 679], [10, 11, 424, 2057], [10, 286], [10, 423, 424, 425], [10, 423, 432, 2042], [17, 18, 19], [16, 545, 547, 548], [16, 553, 3834, 3835], [16, 35, 1206], [21, 22, 23], [20, 1492, 1728], [20, 884, 885], [20, 73], [25, 26, 27, 28, 29], [24, 1360, 3806, 3822], [24, 27, 3680, 3824], [24, 26, 1877, 3817], [24, 638, 3808, 3812], [24, 1712, 3814, 3819], [31, 32, 33, 34], [30, 631], [30, 630, 1831], [30, 640, 1595], [30, 2511], [19, 36, 37, 38], [35, 544, 545, 546], [35, 1212, 1214], [35, 1234, 1319], [40, 41, 42, 43, 44], [39, 1856], [39, 647, 1855], [39, 1516, 1577], [39, 2929], [39, 347, 3211], [46, 47, 48, 49], [45, 929, 2108, 2109, 2110], [45, 1405, 1729, 1730], [45, 88, 464], [45, 87, 1729, 2109], [51, 52, 53], [50, 458, 789], [50, 450, 452], [50, 1731], [55, 56, 57], [54, 76, 77], [54, 63, 64], [54, 220], [59, 60, 61], [58, 69], [58, 74, 1736, 1789], [58, 62, 63], [61], [56, 61, 2690], [56, 65, 66], [64, 67], [64, 447, 2694], [65, 68], [67, 99, 867, 869], [59, 2687], [71, 72, 73, 74], [70], [70, 1758], [23, 70, 75], [60, 70, 2711], [73], [55, 1718], [55, 1608, 1846], [79, 80, 81, 82], [78, 935, 3236], [78, 370, 1580, 1791], [78, 83, 84], [78, 1812], [81, 1780, 1864], [81, 85, 86, 87], [84, 346, 1519], [84, 1106, 1791, 2107], [49, 84, 1615], [48, 89, 90], [88, 791, 1781], [88, 91], [90, 92, 93, 94], [91, 453], [91, 1546, 1794, 1888], [91, 95], [94, 96], [95, 97, 98], [96, 437, 1196], [96, 99, 100, 101], [68, 98, 1383], [98, 1456, 1546, 2112], [98, 471, 472], [103, 104, 105], [102, 761, 765], [102, 763, 764], [102, 1606], [107], [106, 1974], [109, 110], [108, 2024], [108, 2022], [112, 113], [111, 292, 373], [111, 114], [113, 115, 116], [114, 2060], [114, 117], [116, 2050, 2051], [119, 120, 121, 122], [118, 523, 712, 2676], [118, 123], [118, 125, 698, 709, 710], [118], [120, 124, 125, 126], [123, 699, 2466, 2638], [121, 123, 698, 699, 700], [123, 840], [128, 129, 130, 131], [127, 324, 325], [127, 703, 704], [127, 2653, 3427], [127, 703, 1055, 2674], [133, 134, 135], [132, 1057], [132, 701, 702], [132, 720], [137, 138], [136, 139], [136, 719, 720], [137, 733, 734], [141, 142, 143], [140, 734], [140, 311, 312], [140, 1921, 1922], [145, 146, 147, 148], [144, 150, 1351, 1419], [144, 531, 534], [144, 528, 534, 1521], [144, 533, 535], [150, 151, 152, 153], [145, 149], [149, 154, 2747], [149, 974, 1342], [149, 1419], [151, 155], [154, 505], [157, 158, 159, 160, 161], [156, 255, 256, 257], [156, 162, 3148], [156, 2537], [156, 186, 187], [156, 2535], [158, 163, 164, 165, 166], [162, 168, 3006], [162, 185], [162, 2591], [162, 192, 1943, 1945], [168, 169, 170], [163, 167, 2725], [167, 171, 3381], [167, 1120, 2795], [169, 172, 173, 174], [171, 177, 3147], [171, 3107, 3108], [171, 4018], [176, 177, 178], [175, 179], [172, 175, 2718, 2721], [175, 267, 2521], [176, 565, 2723], [181, 182], [180, 566, 2715], [180, 183], [182, 185, 2528, 2590], [185, 186], [164, 183, 184, 261], [160, 184, 2968], [160, 188], [187, 2534], [190, 191], [189, 214], [189, 2532, 2957, 2960, 2967], [166, 193], [192, 1117], [195, 196, 197, 198], [194, 2542], [194, 2533], [194, 199, 2016], [194, 215], [197, 200], [199, 201], [200, 202, 730], [201, 203, 204], [202, 205, 2456], [202, 2456, 2463, 2627], [203, 206, 207], [205, 208, 2456, 2621], [205, 208, 209], [206, 207, 2438, 2606], [207, 210, 211], [209, 2013], [209, 212], [211, 213], [212, 214, 2015], [190, 213, 215], [198, 214], [217, 218, 219, 220], [216, 473, 1572], [216, 1846, 1854], [216, 2441, 2444, 2445], [57, 216, 1572, 1846], [222, 223, 224, 225, 226, 227, 228, 229], [221, 1813], [221, 230], [221, 2757], [221, 1622, 1859], [221, 1815], [221, 2450], [221, 2439], [221, 880], [223, 2443], [232, 233], [231, 2930, 2973], [231, 235], [235, 236], [233, 234, 871, 873], [234, 237], [236], [239, 240, 241, 242], [238, 974, 1283] ...
#
# ######## Preprocessing the graph...
# 100%|██████████| 4021/4021 [00:03<00:00, 1067.92it/s]
# Preprocessing time: 3.79660320
#
# ######## Query Testing...
# The shortest distance between 729 and 2682 is: (output = 26, expected = 26) True
# The shortest distance between 962 and 1522 is: (output = 12, expected = 12) True
# The shortest distance between 1606 and 310 is: (output = 23, expected = 23) True
# The shortest distance between 577 and 1452 is: (output = 26, expected = 26) True
# The shortest distance between 718 and 3189 is: (output = 28, expected = 28) True
# The shortest distance between 579 and 1485 is: (output = 27, expected = 27) True
# The shortest distance between 2173 and 460 is: (output = 43, expected = 43) True
# The shortest distance between 1811 and 1234 is: (output = 27, expected = 27) True
# The shortest distance between 1108 and 366 is: (output = 7, expected = 7) True
# The shortest distance between 2371 and 3243 is: (output = 31, expected = 31) True
# The shortest distance between 2856 and 3271 is: (output = 51, expected = 51) True
# The shortest distance between 1306 and 1880 is: (output = 28, expected = 28) True
# The shortest distance between 1590 and 890 is: (output = 33, expected = 33) True
# The shortest distance between 2125 and 3152 is: (output = 22, expected = 22) True
# The shortest distance between 3718 and 2439 is: (output = 40, expected = 40) True
# The shortest distance between 2813 and 834 is: (output = 37, expected = 37) True
# The shortest distance between 421 and 996 is: (output = 28, expected = 28) True
# The shortest distance between 919 and 2486 is: (output = 31, expected = 31) True
# The shortest distance between 3132 and 1234 is: (output = 51, expected = 51) True
# The shortest distance between 3769 and 1971 is: (output = 39, expected = 39) True
# The shortest distance between 3950 and 723 is: (output = 26, expected = 26) True
# The shortest distance between 672 and 2977 is: (output = 48, expected = 48) True
# The shortest distance between 590 and 389 is: (output = 19, expected = 19) True
# The shortest distance between 1968 and 72 is: (output = 32, expected = 32) True
# The shortest distance between 2801 and 773 is: (output = 43, expected = 43) True
# The shortest distance between 1373 and 170 is: (output = 45, expected = 45) True
# The shortest distance between 657 and 2363 is: (output = 49, expected = 49) True
# The shortest distance between 2664 and 3066 is: (output = 44, expected = 44) True
# The shortest distance between 1421 and 2062 is: (output = 25, expected = 25) True
# The shortest distance between 3254 and 3393 is: (output = 48, expected = 48) True
# The shortest distance between 2763 and 3238 is: (output = 46, expected = 46) True
# The shortest distance between 1675 and 2113 is: (output = 14, expected = 14) True
# The shortest distance between 980 and 1201 is: (output = 33, expected = 33) True
# The shortest distance between 1702 and 2595 is: (output = 40, expected = 40) True
# The shortest distance between 3308 and 2775 is: (output = 8, expected = 8) True
# The shortest distance between 2148 and 870 is: (output = 61, expected = 61) True
# The shortest distance between 3735 and 3060 is: (output = 28, expected = 28) True
# The shortest distance between 3882 and 3146 is: (output = 67, expected = 67) True
# The shortest distance between 994 and 1056 is: (output = 19, expected = 19) True
# The shortest distance between 295 and 1266 is: (output = 46, expected = 46) True
# The shortest distance between 427 and 906 is: (output = 46, expected = 46) True
# The shortest distance between 3262 and 875 is: (output = 32, expected = 32) True
# The shortest distance between 1770 and 89 is: (output = 11, expected = 11) True
# The shortest distance between 2439 and 2282 is: (output = 56, expected = 56) True
# The shortest distance between 403 and 2086 is: (output = 16, expected = 16) True
# The shortest distance between 2277 and 3845 is: (output = 53, expected = 53) True
# The shortest distance between 1994 and 3923 is: (output = 46, expected = 46) True
# The shortest distance between 1140 and 1376 is: (output = 35, expected = 35) True
# The shortest distance between 3626 and 2940 is: (output = 25, expected = 25) True
# The shortest distance between 1435 and 2298 is: (output = 50, expected = 50) True
# The shortest distance between 3287 and 3096 is: (output = 38, expected = 38) True
# The shortest distance between 2150 and 2762 is: (output = 51, expected = 51) True
# The shortest distance between 65 and 2875 is: (output = 21, expected = 21) True
# The shortest distance between 3959 and 1203 is: (output = 47, expected = 47) True
# The shortest distance between 2934 and 2988 is: (output = 32, expected = 32) True
# The shortest distance between 3820 and 1517 is: (output = 15, expected = 15) True
# The shortest distance between 1046 and 48 is: (output = 10, expected = 10) True
# The shortest distance between 364 and 3230 is: (output = 39, expected = 39) True
# The shortest distance between 1710 and 2110 is: (output = 18, expected = 18) True
# The shortest distance between 1890 and 2940 is: (output = 40, expected = 40) True
# The shortest distance between 1081 and 1613 is: (output = 16, expected = 16) True
# The shortest distance between 2951 and 3773 is: (output = 25, expected = 25) True
# The shortest distance between 2456 and 2571 is: (output = 25, expected = 25) True
# The shortest distance between 2295 and 2281 is: (output = 2, expected = 2) True
# The shortest distance between 1464 and 3638 is: (output = 51, expected = 51) True
# The shortest distance between 2695 and 648 is: (output = 22, expected = 22) True
# The shortest distance between 1892 and 3050 is: (output = 59, expected = 59) True
# The shortest distance between 815 and 3061 is: (output = 36, expected = 36) True
# The shortest distance between 1134 and 3219 is: (output = 50, expected = 50) True
# The shortest distance between 1366 and 555 is: (output = 27, expected = 27) True
# The shortest distance between 170 and 3212 is: (output = 38, expected = 38) True
# The shortest distance between 2314 and 2314 is: (output = 0, expected = 0) True
# The shortest distance between 1743 and 932 is: (output = 10, expected = 10) True
# The shortest distance between 106 and 3740 is: (output = 37, expected = 37) True
# The shortest distance between 3677 and 2808 is: (output = 71, expected = 71) True
# The shortest distance between 969 and 2455 is: (output = 29, expected = 29) True
# The shortest distance between 3228 and 2014 is: (output = 23, expected = 23) True
# The shortest distance between 196 and 3223 is: (output = 15, expected = 15) True
# The shortest distance between 3299 and 2332 is: (output = 29, expected = 29) True
# The shortest distance between 1603 and 3964 is: (output = 32, expected = 32) True
# The shortest distance between 2337 and 2750 is: (output = 54, expected = 54) True
# The shortest distance between 3163 and 122 is: (output = 16, expected = 16) True
# The shortest distance between 1301 and 23 is: (output = 16, expected = 16) True
# The shortest distance between 126 and 3161 is: (output = 8, expected = 8) True
# The shortest distance between 2735 and 1113 is: (output = 41, expected = 41) True
# The shortest distance between 1338 and 3628 is: (output = 24, expected = 24) True
# The shortest distance between 82 and 1225 is: (output = 27, expected = 27) True
# The shortest distance between 531 and 1216 is: (output = 11, expected = 11) True
# The shortest distance between 3900 and 1775 is: (output = 39, expected = 39) True
# The shortest distance between 1228 and 1875 is: (output = 32, expected = 32) True
# The shortest distance between 1380 and 2775 is: (output = 32, expected = 32) True
# The shortest distance between 2568 and 2502 is: (output = 47, expected = 47) True
# The shortest distance between 2024 and 1198 is: (output = 18, expected = 18) True
# The shortest distance between 1618 and 539 is: (output = 27, expected = 27) True
# The shortest distance between 3281 and 2050 is: (output = 22, expected = 22) True
# The shortest distance between 1789 and 3911 is: (output = 17, expected = 17) True
# The shortest distance between 449 and 2467 is: (output = 31, expected = 31) True
# The shortest distance between 1511 and 1053 is: (output = 23, expected = 23) True
# The shortest distance between 3654 and 3782 is: (output = 49, expected = 49) True
# The shortest distance between 2278 and 1600 is: (output = 49, expected = 49) True
# The shortest distance between 2861 and 716 is: (output = 35, expected = 35) True
# The shortest distance between 486 and 3127 is: (output = 43, expected = 43) True
# The shortest distance between 3257 and 3287 is: (output = 14, expected = 14) True
# The shortest distance between 186 and 3359 is: (output = 37, expected = 37) True
# The shortest distance between 2161 and 1100 is: (output = 29, expected = 29) True
# The shortest distance between 2869 and 1271 is: (output = 52, expected = 52) True
# The shortest distance between 465 and 1623 is: (output = 25, expected = 25) True
# The shortest distance between 431 and 452 is: (output = 29, expected = 29) True
# The shortest distance between 813 and 859 is: (output = 17, expected = 17) True
# The shortest distance between 3989 and 1505 is: (output = 26, expected = 26) True
# The shortest distance between 387 and 1050 is: (output = 19, expected = 19) True
# The shortest distance between 1011 and 3451 is: (output = 58, expected = 58) True
# The shortest distance between 959 and 750 is: (output = 50, expected = 50) True
# The shortest distance between 3168 and 2525 is: (output = 38, expected = 38) True
# The shortest distance between 642 and 1788 is: (output = 16, expected = 16) True
# The shortest distance between 3335 and 559 is: (output = 18, expected = 18) True
# The shortest distance between 3303 and 1681 is: (output = 16, expected = 16) True
# The shortest distance between 1938 and 3879 is: (output = 51, expected = 51) True
# The shortest distance between 83 and 3413 is: (output = 18, expected = 18) True
# The shortest distance between 1252 and 3823 is: (output = 21, expected = 21) True
# The shortest distance between 2792 and 1282 is: (output = 63, expected = 63) True
# The shortest distance between 2510 and 2719 is: (output = 39, expected = 39) True
# The shortest distance between 256 and 1435 is: (output = 53, expected = 53) True
# The shortest distance between 1936 and 1989 is: (output = 30, expected = 30) True
# The shortest distance between 2906 and 2271 is: (output = 45, expected = 45) True
# The shortest distance between 266 and 1811 is: (output = 27, expected = 27) True
# The shortest distance between 3610 and 1256 is: (output = 28, expected = 28) True
# The shortest distance between 2582 and 51 is: (output = 30, expected = 30) True
# The shortest distance between 561 and 2702 is: (output = 21, expected = 21) True
# The shortest distance between 1589 and 1501 is: (output = 39, expected = 39) True
# The shortest distance between 309 and 56 is: (output = 30, expected = 30) True
# The shortest distance between 1945 and 3611 is: (output = 65, expected = 65) True
# The shortest distance between 610 and 99 is: (output = 25, expected = 25) True
# The shortest distance between 3778 and 420 is: (output = 39, expected = 39) True
# The shortest distance between 3895 and 1842 is: (output = 46, expected = 46) True
# The shortest distance between 105 and 2174 is: (output = 42, expected = 42) True
# The shortest distance between 1626 and 3380 is: (output = 39, expected = 39) True
# The shortest distance between 1805 and 3962 is: (output = 47, expected = 47) True
# The shortest distance between 2179 and 2917 is: (output = 44, expected = 44) True
# The shortest distance between 180 and 3093 is: (output = 36, expected = 36) True
# The shortest distance between 3802 and 848 is: (output = 42, expected = 42) True
# The shortest distance between 983 and 210 is: (output = 11, expected = 11) True
# The shortest distance between 2352 and 2826 is: (output = 33, expected = 33) True
# The shortest distance between 2392 and 676 is: (output = 31, expected = 31) True
# The shortest distance between 3732 and 3511 is: (output = 48, expected = 48) True
# The shortest distance between 1207 and 1538 is: (output = 42, expected = 42) True
# The shortest distance between 2269 and 820 is: (output = 53, expected = 53) True
# The shortest distance between 1221 and 2924 is: (output = 31, expected = 31) True
# The shortest distance between 3530 and 397 is: (output = 35, expected = 35) True
# The shortest distance between 1009 and 3851 is: (output = 42, expected = 42) True
# The shortest distance between 2723 and 10 is: (output = 21, expected = 21) True
# The shortest distance between 97 and 3567 is: (output = 39, expected = 39) True
# The shortest distance between 1059 and 2989 is: (output = 63, expected = 63) True
# The shortest distance between 3904 and 1757 is: (output = 17, expected = 17) True
# The shortest distance between 3320 and 2115 is: (output = 39, expected = 39) True
# The shortest distance between 3412 and 967 is: (output = 38, expected = 38) True
# The shortest distance between 602 and 606 is: (output = 1, expected = 1) True
# The shortest distance between 3391 and 1871 is: (output = 45, expected = 45) True
# The shortest distance between 1236 and 2258 is: (output = 65, expected = 65) True
# The shortest distance between 3924 and 1053 is: (output = 28, expected = 28) True
# The shortest distance between 3777 and 2347 is: (output = 44, expected = 44) True
# The shortest distance between 2218 and 2005 is: (output = 37, expected = 37) True
# The shortest distance between 607 and 3127 is: (output = 40, expected = 40) True
# The shortest distance between 924 and 2824 is: (output = 32, expected = 32) True
# The shortest distance between 2856 and 949 is: (output = 50, expected = 50) True
# The shortest distance between 3294 and 3761 is: (output = 22, expected = 22) True
# The shortest distance between 2788 and 781 is: (output = 41, expected = 41) True
# The shortest distance between 2949 and 1625 is: (output = 34, expected = 34) True
# The shortest distance between 3222 and 2960 is: (output = 11, expected = 11) True
# The shortest distance between 3077 and 2031 is: (output = 26, expected = 26) True
# The shortest distance between 2458 and 33 is: (output = 23, expected = 23) True
# The shortest distance between 1354 and 3718 is: (output = 24, expected = 24) True
# The shortest distance between 2405 and 3946 is: (output = 47, expected = 47) True
# The shortest distance between 2032 and 1383 is: (output = 14, expected = 14) True
# The shortest distance between 2763 and 164 is: (output = 32, expected = 32) True
# The shortest distance between 4017 and 2817 is: (output = 23, expected = 23) True
# The shortest distance between 1464 and 953 is: (output = 35, expected = 35) True
# The shortest distance between 3836 and 1257 is: (output = 18, expected = 18) True
# The shortest distance between 1620 and 1058 is: (output = 43, expected = 43) True
# The shortest distance between 3179 and 3123 is: (output = 36, expected = 36) True
# The shortest distance between 623 and 1604 is: (output = 25, expected = 25) True
# The shortest distance between 3087 and 35 is: (output = 51, expected = 51) True
# The shortest distance between 1021 and 100 is: (output = 17, expected = 17) True
# The shortest distance between 2898 and 593 is: (output = 27, expected = 27) True
# The shortest distance between 1617 and 508 is: (output = 26, expected = 26) True
# The shortest distance between 2531 and 2858 is: (output = 43, expected = 43) True
# The shortest distance between 2593 and 2328 is: (output = 27, expected = 27) True
# The shortest distance between 1228 and 351 is: (output = 30, expected = 30) True
# The shortest distance between 1171 and 543 is: (output = 33, expected = 33) True
# The shortest distance between 2279 and 223 is: (output = 50, expected = 50) True
# The shortest distance between 126 and 1526 is: (output = 23, expected = 23) True
# The shortest distance between 569 and 1356 is: (output = 19, expected = 19) True
# The shortest distance between 3860 and 3528 is: (output = 34, expected = 34) True
# The shortest distance between 799 and 1606 is: (output = 14, expected = 14) True
# The shortest distance between 2520 and 2623 is: (output = 16, expected = 16) True
# The shortest distance between 1262 and 2081 is: (output = 23, expected = 23) True
# The shortest distance between 3354 and 3063 is: (output = 23, expected = 23) True
# The shortest distance between 2354 and 3231 is: (output = 26, expected = 26) True
# The shortest distance between 1608 and 3001 is: (output = 39, expected = 39) True
# The shortest distance between 343 and 200 is: (output = 26, expected = 26) True
# The shortest distance between 2822 and 1358 is: (output = 42, expected = 42) True
# The shortest distance between 1337 and 1813 is: (output = 26, expected = 26) True
# The shortest distance between 1846 and 3178 is: (output = 23, expected = 23) True
# The shortest distance between 1800 and 3549 is: (output = 26, expected = 26) True
# The shortest distance between 355 and 2857 is: (output = 44, expected = 44) True
# The shortest distance between 32 and 1608 is: (output = 23, expected = 23) True
# The shortest distance between 3651 and 2711 is: (output = 45, expected = 45) True
# The shortest distance between 515 and 297 is: (output = 38, expected = 38) True
# The shortest distance between 2968 and 815 is: (output = 29, expected = 29) True
# The shortest distance between 3962 and 3006 is: (output = 38, expected = 38) True
# The shortest distance between 2486 and 2615 is: (output = 25, expected = 25) True
# The shortest distance between 2124 and 3142 is: (output = 43, expected = 43) True
# The shortest distance between 1808 and 2516 is: (output = 44, expected = 44) True
# The shortest distance between 1862 and 1808 is: (output = 19, expected = 19) True
# The shortest distance between 1042 and 205 is: (output = 6, expected = 6) True
# The shortest distance between 2463 and 2213 is: (output = 39, expected = 39) True
# The shortest distance between 342 and 1302 is: (output = 29, expected = 29) True
# The shortest distance between 1504 and 1010 is: (output = 34, expected = 34) True
# The shortest distance between 590 and 2749 is: (output = 41, expected = 41) True
# The shortest distance between 2061 and 236 is: (output = 50, expected = 50) True
# The shortest distance between 2476 and 3933 is: (output = 21, expected = 21) True
# The shortest distance between 755 and 2364 is: (output = 50, expected = 50) True
# The shortest distance between 1744 and 3783 is: (output = 20, expected = 20) True
# The shortest distance between 2103 and 849 is: (output = 42, expected = 42) True
# The shortest distance between 1301 and 2523 is: (output = 50, expected = 50) True
# The shortest distance between 329 and 1804 is: (output = 53, expected = 53) True
# The shortest distance between 2120 and 703 is: (output = 52, expected = 52) True
# The shortest distance between 2445 and 1596 is: (output = 29, expected = 29) True
# The shortest distance between 2359 and 3089 is: (output = 36, expected = 36) True
# The shortest distance between 378 and 2922 is: (output = 35, expected = 35) True
# The shortest distance between 198 and 2727 is: (output = 23, expected = 23) True
# The shortest distance between 3485 and 1792 is: (output = 41, expected = 41) True
# The shortest distance between 602 and 16 is: (output = 11, expected = 11) True
# The shortest distance between 1945 and 1490 is: (output = 26, expected = 26) True
# The shortest distance between 1783 and 2190 is: (output = 47, expected = 47) True
# The shortest distance between 628 and 1233 is: (output = 23, expected = 23) True
# The shortest distance between 2320 and 1078 is: (output = 46, expected = 46) True
# The shortest distance between 2871 and 1254 is: (output = 49, expected = 49) True
# The shortest distance between 3290 and 3471 is: (output = 42, expected = 42) True
# The shortest distance between 3993 and 3675 is: (output = 40, expected = 40) True
# The shortest distance between 880 and 68 is: (output = 16, expected = 16) True
# The shortest distance between 3876 and 3306 is: (output = 28, expected = 28) True
# The shortest distance between 3486 and 3278 is: (output = 36, expected = 36) True
# The shortest distance between 921 and 1998 is: (output = 19, expected = 19) True
# The shortest distance between 3867 and 3382 is: (output = 52, expected = 52) True
# The shortest distance between 3537 and 3619 is: (output = 55, expected = 55) True
# The shortest distance between 365 and 3199 is: (output = 32, expected = 32) True
# The shortest distance between 3447 and 755 is: (output = 39, expected = 39) True
# The shortest distance between 944 and 3560 is: (output = 43, expected = 43) True
# The shortest distance between 3014 and 1105 is: (output = 37, expected = 37) True
# The shortest distance between 154 and 880 is: (output = 9, expected = 9) True
# The shortest distance between 3625 and 3460 is: (output = 26, expected = 26) True
# The shortest distance between 3634 and 3586 is: (output = 22, expected = 22) True
# The shortest distance between 948 and 758 is: (output = 33, expected = 33) True
# The shortest distance between 599 and 2013 is: (output = 18, expected = 18) True
# The shortest distance between 2681 and 3298 is: (output = 40, expected = 40) True
# The shortest distance between 3890 and 692 is: (output = 53, expected = 53) True
# The shortest distance between 100 and 2648 is: (output = 21, expected = 21) True
# The shortest distance between 3009 and 713 is: (output = 44, expected = 44) True
# The shortest distance between 1175 and 3430 is: (output = 47, expected = 47) True
# The shortest distance between 2885 and 80 is: (output = 22, expected = 22) True
# The shortest distance between 1611 and 857 is: (output = 37, expected = 37) True
# The shortest distance between 1473 and 271 is: (output = 38, expected = 38) True
# The shortest distance between 2597 and 1053 is: (output = 20, expected = 20) True
# The shortest distance between 3504 and 3565 is: (output = 35, expected = 35) True
# The shortest distance between 1089 and 2309 is: (output = 32, expected = 32) True
# The shortest distance between 1933 and 3675 is: (output = 58, expected = 58) True
# The shortest distance between 365 and 2712 is: (output = 33, expected = 33) True
# The shortest distance between 2902 and 2241 is: (output = 42, expected = 42) True
# The shortest distance between 1871 and 802 is: (output = 24, expected = 24) True
# The shortest distance between 354 and 2921 is: (output = 11, expected = 11) True
# The shortest distance between 3376 and 2205 is: (output = 32, expected = 32) True
# The shortest distance between 89 and 1626 is: (output = 12, expected = 12) True
# The shortest distance between 3566 and 3025 is: (output = 39, expected = 39) True
# The shortest distance between 2368 and 505 is: (output = 57, expected = 57) True
# The shortest distance between 1065 and 2723 is: (output = 26, expected = 26) True
# The shortest distance between 2863 and 1647 is: (output = 42, expected = 42) True
# The shortest distance between 1406 and 1492 is: (output = 18, expected = 18) True
# The shortest distance between 2638 and 1281 is: (output = 35, expected = 35) True
# The shortest distance between 464 and 789 is: (output = 7, expected = 7) True
# The shortest distance between 994 and 2219 is: (output = 45, expected = 45) True
# The shortest distance between 1077 and 3718 is: (output = 34, expected = 34) True
# The shortest distance between 448 and 2511 is: (output = 14, expected = 14) True
# The shortest distance between 1146 and 1163 is: (output = 22, expected = 22) True
# The shortest distance between 2366 and 3354 is: (output = 21, expected = 21) True
# The shortest distance between 307 and 1172 is: (output = 34, expected = 34) True
# The shortest distance between 2219 and 1203 is: (output = 22, expected = 22) True
# The shortest distance between 1420 and 3396 is: (output = 28, expected = 28) True
# The shortest distance between 1822 and 2891 is: (output = 11, expected = 11) True
# The shortest distance between 879 and 313 is: (output = 43, expected = 43) True
# The shortest distance between 2508 and 2768 is: (output = 23, expected = 23) True
# The shortest distance between 2395 and 2560 is: (output = 38, expected = 38) True
# The shortest distance between 568 and 173 is: (output = 12, expected = 12) True
# The shortest distance between 2952 and 3850 is: (output = 7, expected = 7) True
# The shortest distance between 161 and 176 is: (output = 11, expected = 11) True
# The shortest distance between 2212 and 3541 is: (output = 37, expected = 37) True
# The shortest distance between 3359 and 1705 is: (output = 45, expected = 45) True
# The shortest distance between 3549 and 2915 is: (output = 33, expected = 33) True
# The shortest distance between 3489 and 3312 is: (output = 43, expected = 43) True
# The shortest distance between 2680 and 2206 is: (output = 35, expected = 35) True
# The shortest distance between 277 and 3563 is: (output = 51, expected = 51) True
# The shortest distance between 2226 and 3931 is: (output = 72, expected = 72) True
# The shortest distance between 3235 and 1179 is: (output = 28, expected = 28) True
# The shortest distance between 3304 and 397 is: (output = 31, expected = 31) True
# The shortest distance between 3980 and 2180 is: (output = 59, expected = 59) True
# The shortest distance between 2900 and 320 is: (output = 50, expected = 50) True
# The shortest distance between 3818 and 1097 is: (output = 37, expected = 37) True
# The shortest distance between 3978 and 2137 is: (output = 48, expected = 48) True
# The shortest distance between 2434 and 2638 is: (output = 22, expected = 22) True
# The shortest distance between 2105 and 171 is: (output = 31, expected = 31) True
# The shortest distance between 3563 and 677 is: (output = 48, expected = 48) True
# The shortest distance between 3109 and 2338 is: (output = 33, expected = 33) True
# The shortest distance between 2335 and 707 is: (output = 42, expected = 42) True
# The shortest distance between 3719 and 1874 is: (output = 46, expected = 46) True
# The shortest distance between 473 and 2593 is: (output = 11, expected = 11) True
# The shortest distance between 573 and 144 is: (output = 35, expected = 35) True
# The shortest distance between 155 and 3343 is: (output = 47, expected = 47) True
# The shortest distance between 1744 and 1366 is: (output = 19, expected = 19) True
# The shortest distance between 3094 and 900 is: (output = 38, expected = 38) True
# The shortest distance between 1928 and 3679 is: (output = 49, expected = 49) True
# The shortest distance between 305 and 419 is: (output = 16, expected = 16) True
# The shortest distance between 2762 and 3062 is: (output = 36, expected = 36) True
# The shortest distance between 3621 and 3485 is: (output = 23, expected = 23) True
# The shortest distance between 1453 and 1358 is: (output = 19, expected = 19) True
# The shortest distance between 3576 and 3150 is: (output = 57, expected = 57) True
# The shortest distance between 2296 and 1457 is: (output = 38, expected = 38) True
# The shortest distance between 1407 and 924 is: (output = 10, expected = 10) True
# The shortest distance between 536 and 1735 is: (output = 25, expected = 25) True
# The shortest distance between 3748 and 3729 is: (output = 33, expected = 33) True
# The shortest distance between 1235 and 2187 is: (output = 53, expected = 53) True
# The shortest distance between 3631 and 2290 is: (output = 79, expected = 79) True
# The shortest distance between 1898 and 3161 is: (output = 13, expected = 13) True
# The shortest distance between 2148 and 2170 is: (output = 27, expected = 27) True
# The shortest distance between 3784 and 3338 is: (output = 27, expected = 27) True
# The shortest distance between 3862 and 985 is: (output = 32, expected = 32) True
# The shortest distance between 1137 and 3210 is: (output = 33, expected = 33) True
# The shortest distance between 1374 and 3949 is: (output = 51, expected = 51) True
# The shortest distance between 1497 and 424 is: (output = 40, expected = 40) True
# The shortest distance between 2316 and 0 is: (output = 33, expected = 33) True
# The shortest distance between 1612 and 2961 is: (output = 34, expected = 34) True
# The shortest distance between 1417 and 3935 is: (output = 26, expected = 26) True
# The shortest distance between 1242 and 2636 is: (output = 40, expected = 40) True
# The shortest distance between 2403 and 780 is: (output = 45, expected = 45) True
# The shortest distance between 4004 and 20 is: (output = 35, expected = 35) True
# The shortest distance between 1860 and 2458 is: (output = 11, expected = 11) True
# The shortest distance between 1010 and 1412 is: (output = 41, expected = 41) True
# The shortest distance between 932 and 589 is: (output = 3, expected = 3) True
# The shortest distance between 1333 and 3998 is: (output = 35, expected = 35) True
# The shortest distance between 675 and 326 is: (output = 33, expected = 33) True
# The shortest distance between 3062 and 2985 is: (output = 67, expected = 67) True
# The shortest distance between 698 and 2766 is: (output = 41, expected = 41) True
# The shortest distance between 1624 and 1646 is: (output = 41, expected = 41) True
# The shortest distance between 35 and 1810 is: (output = 9, expected = 9) True
# The shortest distance between 414 and 1222 is: (output = 49, expected = 49) True
# The shortest distance between 3839 and 2873 is: (output = 37, expected = 37) True
# The shortest distance between 743 and 2737 is: (output = 44, expected = 44) True
# The shortest distance between 2885 and 1933 is: (output = 22, expected = 22) True
# The shortest distance between 23 and 1645 is: (output = 37, expected = 37) True
# The shortest distance between 816 and 3207 is: (output = 23, expected = 23) True
# The shortest distance between 2753 and 2281 is: (output = 74, expected = 74) True
# The shortest distance between 335 and 2419 is: (output = 27, expected = 27) True
# The shortest distance between 1182 and 249 is: (output = 6, expected = 6) True
# The shortest distance between 1819 and 3485 is: (output = 34, expected = 34) True
# The shortest distance between 419 and 466 is: (output = 26, expected = 26) True
# The shortest distance between 894 and 3868 is: (output = 17, expected = 17) True
# The shortest distance between 504 and 3108 is: (output = 44, expected = 44) True
# The shortest distance between 2854 and 3203 is: (output = 34, expected = 34) True
# The shortest distance between 2914 and 3468 is: (output = 40, expected = 40) True
# The shortest distance between 1108 and 343 is: (output = 8, expected = 8) True
# The shortest distance between 1643 and 1577 is: (output = 13, expected = 13) True
# The shortest distance between 2257 and 2998 is: (output = 81, expected = 81) True
# The shortest distance between 2464 and 317 is: (output = 33, expected = 33) True
# The shortest distance between 3828 and 1094 is: (output = 45, expected = 45) True
# The shortest distance between 137 and 392 is: (output = 29, expected = 29) True
# The shortest distance between 3825 and 3006 is: (output = 45, expected = 45) True
# The shortest distance between 233 and 3616 is: (output = 38, expected = 38) True
# The shortest distance between 1163 and 1455 is: (output = 33, expected = 33) True
# The shortest distance between 151 and 1953 is: (output = 35, expected = 35) True
# The shortest distance between 297 and 2235 is: (output = 21, expected = 21) True
# The shortest distance between 3828 and 2003 is: (output = 34, expected = 34) True
# The shortest distance between 4006 and 119 is: (output = 48, expected = 48) True
# The shortest distance between 108 and 1364 is: (output = 27, expected = 27) True
# The shortest distance between 2687 and 1528 is: (output = 28, expected = 28) True
# The shortest distance between 2337 and 2026 is: (output = 34, expected = 34) True
# The shortest distance between 80 and 330 is: (output = 37, expected = 37) True
# The shortest distance between 2783 and 4016 is: (output = 18, expected = 18) True
# The shortest distance between 2510 and 2958 is: (output = 39, expected = 39) True
# The shortest distance between 541 and 1018 is: (output = 38, expected = 38) True
# The shortest distance between 1938 and 2204 is: (output = 27, expected = 27) True
# The shortest distance between 863 and 3268 is: (output = 28, expected = 28) True
# The shortest distance between 352 and 3199 is: (output = 37, expected = 37) True
# The shortest distance between 3669 and 3687 is: (output = 37, expected = 37) True
# The shortest distance between 363 and 3888 is: (output = 53, expected = 53) True
# The shortest distance between 1621 and 699 is: (output = 43, expected = 43) True
# The shortest distance between 687 and 1853 is: (output = 11, expected = 11) True
# The shortest distance between 2780 and 3102 is: (output = 50, expected = 50) True
# The shortest distance between 2952 and 1445 is: (output = 28, expected = 28) True
# The shortest distance between 2170 and 2142 is: (output = 34, expected = 34) True
# The shortest distance between 2293 and 3942 is: (output = 45, expected = 45) True
# The shortest distance between 1054 and 1870 is: (output = 37, expected = 37) True
# The shortest distance between 3610 and 1869 is: (output = 47, expected = 47) True
# The shortest distance between 2214 and 2432 is: (output = 45, expected = 45) True
# The shortest distance between 2657 and 1908 is: (output = 21, expected = 21) True
# The shortest distance between 3296 and 2209 is: (output = 32, expected = 32) True
# The shortest distance between 1125 and 2367 is: (output = 59, expected = 59) True
# The shortest distance between 1433 and 418 is: (output = 40, expected = 40) True
# The shortest distance between 416 and 1748 is: (output = 25, expected = 25) True
# The shortest distance between 1767 and 3237 is: (output = 34, expected = 34) True
# The shortest distance between 378 and 3930 is: (output = 46, expected = 46) True
# The shortest distance between 3901 and 3364 is: (output = 56, expected = 56) True
# The shortest distance between 3774 and 3034 is: (output = 44, expected = 44) True
# The shortest distance between 3819 and 57 is: (output = 19, expected = 19) True
# The shortest distance between 3985 and 3277 is: (output = 45, expected = 45) True
# The shortest distance between 685 and 2938 is: (output = 24, expected = 24) True
# The shortest distance between 1073 and 1739 is: (output = 29, expected = 29) True
# The shortest distance between 3398 and 1795 is: (output = 31, expected = 31) True
# The shortest distance between 1394 and 40 is: (output = 16, expected = 16) True
# The shortest distance between 2457 and 324 is: (output = 16, expected = 16) True
# The shortest distance between 2430 and 1470 is: (output = 42, expected = 42) True
# The shortest distance between 388 and 3382 is: (output = 19, expected = 19) True
# The shortest distance between 3019 and 112 is: (output = 25, expected = 25) True
# The shortest distance between 1797 and 707 is: (output = 36, expected = 36) True
# The shortest distance between 2833 and 400 is: (output = 40, expected = 40) True
# The shortest distance between 335 and 498 is: (output = 34, expected = 34) True
# The shortest distance between 3252 and 1199 is: (output = 33, expected = 33) True
# The shortest distance between 3584 and 2480 is: (output = 41, expected = 41) True
# The shortest distance between 3328 and 1733 is: (output = 26, expected = 26) True
# The shortest distance between 3506 and 3862 is: (output = 23, expected = 23) True
# The shortest distance between 1314 and 3883 is: (output = 42, expected = 42) True
# The shortest distance between 2983 and 3017 is: (output = 70, expected = 70) True
# The shortest distance between 2315 and 3995 is: (output = 31, expected = 31) True
# The shortest distance between 1822 and 1532 is: (output = 20, expected = 20) True
# The shortest distance between 2346 and 2676 is: (output = 60, expected = 60) True
# The shortest distance between 3948 and 911 is: (output = 28, expected = 28) True
# The shortest distance between 3382 and 2311 is: (output = 9, expected = 9) True
# The shortest distance between 422 and 2019 is: (output = 8, expected = 8) True
# The shortest distance between 3647 and 188 is: (output = 66, expected = 66) True
# The shortest distance between 1857 and 43 is: (output = 20, expected = 20) True
# The shortest distance between 3430 and 619 is: (output = 41, expected = 41) True
# The shortest distance between 2342 and 2950 is: (output = 55, expected = 55) True
# The shortest distance between 3143 and 2785 is: (output = 17, expected = 17) True
# The shortest distance between 2319 and 467 is: (output = 45, expected = 45) True
# The shortest distance between 1922 and 2106 is: (output = 38, expected = 38) True
# The shortest distance between 3335 and 1133 is: (output = 40, expected = 40) True
# The shortest distance between 3537 and 2599 is: (output = 43, expected = 43) True
# The shortest distance between 688 and 433 is: (output = 20, expected = 20) True
# The shortest distance between 2434 and 1602 is: (output = 30, expected = 30) True
# The shortest distance between 934 and 1055 is: (output = 32, expected = 32) True
# The shortest distance between 1026 and 3993 is: (output = 30, expected = 30) True
# The shortest distance between 1075 and 2190 is: (output = 49, expected = 49) True
# The shortest distance between 461 and 986 is: (output = 18, expected = 18) True
# The shortest distance between 2051 and 1798 is: (output = 38, expected = 38) True
# The shortest distance between 545 and 2064 is: (output = 37, expected = 37) True
# The shortest distance between 2610 and 2388 is: (output = 42, expected = 42) True
# The shortest distance between 699 and 1638 is: (output = 44, expected = 44) True
# The shortest distance between 1630 and 3000 is: (output = 21, expected = 21) True
# The shortest distance between 3186 and 5 is: (output = 45, expected = 45) True
# The shortest distance between 3247 and 1125 is: (output = 48, expected = 48) True
# The shortest distance between 2735 and 3840 is: (output = 32, expected = 32) True
# The shortest distance between 1847 and 3253 is: (output = 38, expected = 38) True
# The shortest distance between 1616 and 403 is: (output = 30, expected = 30) True
# The shortest distance between 639 and 467 is: (output = 18, expected = 18) True
# The shortest distance between 2210 and 1531 is: (output = 38, expected = 38) True
# The shortest distance between 3305 and 506 is: (output = 38, expected = 38) True
# The shortest distance between 595 and 2537 is: (output = 28, expected = 28) True
# The shortest distance between 3893 and 647 is: (output = 28, expected = 28) True
# The shortest distance between 2748 and 1332 is: (output = 45, expected = 45) True
# The shortest distance between 2832 and 2979 is: (output = 71, expected = 71) True
# The shortest distance between 2414 and 2392 is: (output = 68, expected = 68) True
# The shortest distance between 1753 and 51 is: (output = 30, expected = 30) True
# The shortest distance between 3501 and 1781 is: (output = 29, expected = 29) True
# The shortest distance between 1673 and 3631 is: (output = 34, expected = 34) True
# The shortest distance between 2785 and 3280 is: (output = 22, expected = 22) True
# The shortest distance between 1833 and 877 is: (output = 29, expected = 29) True
# The shortest distance between 112 and 3851 is: (output = 33, expected = 33) True
# The shortest distance between 1105 and 946 is: (output = 8, expected = 8) True
# The shortest distance between 1362 and 3567 is: (output = 26, expected = 26) True
# The shortest distance between 3895 and 3131 is: (output = 56, expected = 56) True
# The shortest distance between 2993 and 3120 is: (output = 81, expected = 81) True
# The shortest distance between 118 and 1276 is: (output = 17, expected = 17) True
# The shortest distance between 2449 and 2805 is: (output = 31, expected = 31) True
# The shortest distance between 3632 and 2052 is: (output = 56, expected = 56) True
# The shortest distance between 898 and 1210 is: (output = 19, expected = 19) True
# The shortest distance between 3549 and 2657 is: (output = 26, expected = 26) True
# The shortest distance between 2854 and 923 is: (output = 19, expected = 19) True
# The shortest distance between 320 and 2231 is: (output = 35, expected = 35) True
# The shortest distance between 2338 and 3148 is: (output = 30, expected = 30) True
# The shortest distance between 934 and 1763 is: (output = 33, expected = 33) True
# The shortest distance between 3203 and 3380 is: (output = 47, expected = 47) True
# The shortest distance between 1149 and 2226 is: (output = 66, expected = 66) True
# The shortest distance between 3350 and 1490 is: (output = 30, expected = 30) True
# The shortest distance between 2831 and 1256 is: (output = 46, expected = 46) True
# The shortest distance between 1229 and 3482 is: (output = 7, expected = 7) True
# The shortest distance between 1036 and 1613 is: (output = 42, expected = 42) True
# The shortest distance between 7 and 810 is: (output = 38, expected = 38) True
# The shortest distance between 593 and 3666 is: (output = 51, expected = 51) True
# The shortest distance between 131 and 1558 is: (output = 32, expected = 32) True
# The shortest distance between 2402 and 2036 is: (output = 23, expected = 23) True
# The shortest distance between 31 and 3042 is: (output = 51, expected = 51) True
# The shortest distance between 1178 and 3672 is: (output = 39, expected = 39) True
# The shortest distance between 495 and 3504 is: (output = 30, expected = 30) True
# The shortest distance between 3646 and 1573 is: (output = 50, expected = 50) True
# The shortest distance between 2731 and 2496 is: (output = 39, expected = 39) True
# The shortest distance between 875 and 2050 is: (output = 49, expected = 49) True
# The shortest distance between 1562 and 787 is: (output = 25, expected = 25) True
# The shortest distance between 1833 and 2566 is: (output = 31, expected = 31) True
# The shortest distance between 2864 and 707 is: (output = 17, expected = 17) True
# The shortest distance between 3485 and 1657 is: (output = 39, expected = 39) True
# The shortest distance between 3811 and 2926 is: (output = 21, expected = 21) True
# The shortest distance between 1441 and 1596 is: (output = 18, expected = 18) True
# The shortest distance between 586 and 715 is: (output = 24, expected = 24) True
# The shortest distance between 1593 and 1121 is: (output = 32, expected = 32) True
# The shortest distance between 894 and 452 is: (output = 19, expected = 19) True
# The shortest distance between 2787 and 3673 is: (output = 40, expected = 40) True
# The shortest distance between 2550 and 929 is: (output = 25, expected = 25) True
# The shortest distance between 3558 and 2658 is: (output = 47, expected = 47) True
# The shortest distance between 3156 and 3145 is: (output = 43, expected = 43) True
# The shortest distance between 2287 and 1922 is: (output = 34, expected = 34) True
# The shortest distance between 736 and 3855 is: (output = 35, expected = 35) True
# The shortest distance between 1376 and 1457 is: (output = 35, expected = 35) True
# The shortest distance between 2324 and 1265 is: (output = 64, expected = 64) True
# The shortest distance between 350 and 1624 is: (output = 41, expected = 41) True
# The shortest distance between 172 and 3145 is: (output = 3, expected = 3) True
# The shortest distance between 688 and 1853 is: (output = 7, expected = 7) True
# The shortest distance between 3731 and 3561 is: (output = 47, expected = 47) True
# The shortest distance between 2717 and 3771 is: (output = 38, expected = 38) True
# The shortest distance between 585 and 3572 is: (output = 42, expected = 42) True
# The shortest distance between 1582 and 1463 is: (output = 46, expected = 46) True
# The shortest distance between 2176 and 118 is: (output = 47, expected = 47) True
# The shortest distance between 1878 and 1476 is: (output = 31, expected = 31) True
# The shortest distance between 2140 and 1441 is: (output = 33, expected = 33) True
# The shortest distance between 1416 and 3597 is: (output = 34, expected = 34) True
# The shortest distance between 1221 and 3856 is: (output = 9, expected = 9) True
# The shortest distance between 3285 and 2104 is: (output = 2, expected = 2) True
# The shortest distance between 3684 and 3111 is: (output = 39, expected = 39) True
# The shortest distance between 2526 and 768 is: (output = 36, expected = 36) True
# The shortest distance between 2900 and 3752 is: (output = 16, expected = 16) True
# The shortest distance between 1256 and 2316 is: (output = 57, expected = 57) True
# ...
# The shortest distance between 2081 and 2461 is: (output = 44, expected = 44) True
# The shortest distance between 2394 and 166 is: (output = 36, expected = 36) True
# The shortest distance between 2662 and 2299 is: (output = 49, expected = 49) True
# The shortest distance between 1555 and 2281 is: (output = 62, expected = 62) True
# The shortest distance between 3101 and 626 is: (output = 36, expected = 36) True
# The shortest distance between 3426 and 45 is: (output = 30, expected = 30) True
# The shortest distance between 1460 and 233 is: (output = 36, expected = 36) True
# The shortest distance between 572 and 3831 is: (output = 43, expected = 43) True
# The shortest distance between 1058 and 56 is: (output = 25, expected = 25) True
# The shortest distance between 2437 and 860 is: (output = 24, expected = 24) True
# The shortest distance between 1890 and 1734 is: (output = 24, expected = 24) True
# The shortest distance between 2443 and 3966 is: (output = 23, expected = 23) True
# The shortest distance between 3713 and 3385 is: (output = 31, expected = 31) True
# The shortest distance between 3796 and 3793 is: (output = 10, expected = 10) True
# The shortest distance between 1354 and 2645 is: (output = 34, expected = 34) True
# The shortest distance between 1798 and 3144 is: (output = 42, expected = 42) True
# The shortest distance between 3620 and 1829 is: (output = 53, expected = 53) True
# The shortest distance between 2904 and 777 is: (output = 44, expected = 44) True
# The shortest distance between 3007 and 1631 is: (output = 65, expected = 65) True
# The shortest distance between 643 and 2627 is: (output = 27, expected = 27) True
# The shortest distance between 514 and 2951 is: (output = 38, expected = 38) True
# The shortest distance between 373 and 676 is: (output = 13, expected = 13) True
# The shortest distance between 619 and 903 is: (output = 19, expected = 19) True
# The shortest distance between 1656 and 2175 is: (output = 52, expected = 52) True
# The shortest distance between 398 and 39 is: (output = 42, expected = 42) True
# The shortest distance between 1125 and 324 is: (output = 25, expected = 25) True
# The shortest distance between 2453 and 3191 is: (output = 38, expected = 38) True
# The shortest distance between 777 and 1959 is: (output = 20, expected = 20) True
# The shortest distance between 2654 and 1156 is: (output = 33, expected = 33) True
# The shortest distance between 3907 and 2249 is: (output = 57, expected = 57) True
# The shortest distance between 1958 and 849 is: (output = 27, expected = 27) True
# The shortest distance between 1944 and 3350 is: (output = 23, expected = 23) True
# The shortest distance between 2989 and 2385 is: (output = 78, expected = 78) True
# The shortest distance between 1483 and 1781 is: (output = 31, expected = 31) True
# The shortest distance between 1000 and 370 is: (output = 26, expected = 26) True
# The shortest distance between 3916 and 2592 is: (output = 38, expected = 38) True
# The shortest distance between 1386 and 2881 is: (output = 20, expected = 20) True
# The shortest distance between 2328 and 3146 is: (output = 20, expected = 20) True
# The shortest distance between 2626 and 3504 is: (output = 45, expected = 45) True
# The shortest distance between 1431 and 1581 is: (output = 50, expected = 50) True
# The shortest distance between 801 and 2026 is: (output = 24, expected = 24) True
# The shortest distance between 2485 and 1141 is: (output = 43, expected = 43) True
# The shortest distance between 2588 and 1092 is: (output = 28, expected = 28) True
# The shortest distance between 3389 and 2768 is: (output = 30, expected = 30) True
# The shortest distance between 310 and 2132 is: (output = 31, expected = 31) True
# The shortest distance between 1416 and 2076 is: (output = 34, expected = 34) True
# The shortest distance between 3977 and 1587 is: (output = 64, expected = 64) True
# The shortest distance between 3562 and 2180 is: (output = 57, expected = 57) True
# The shortest distance between 2641 and 1998 is: (output = 27, expected = 27) True
# The shortest distance between 1091 and 3092 is: (output = 39, expected = 39) True
# The shortest distance between 1742 and 2136 is: (output = 42, expected = 42) True
# The shortest distance between 3180 and 895 is: (output = 39, expected = 39) True
# The shortest distance between 4007 and 2426 is: (output = 30, expected = 30) True
# The shortest distance between 3387 and 2760 is: (output = 33, expected = 33) True
# The shortest distance between 586 and 3168 is: (output = 38, expected = 38) True
# The shortest distance between 536 and 412 is: (output = 51, expected = 51) True
# The shortest distance between 1505 and 2969 is: (output = 32, expected = 32) True
# The shortest distance between 2664 and 3883 is: (output = 56, expected = 56) True
# The shortest distance between 2711 and 2945 is: (output = 33, expected = 33) True
# The shortest distance between 1119 and 2593 is: (output = 19, expected = 19) True
# The shortest distance between 1412 and 3027 is: (output = 21, expected = 21) True
# The shortest distance between 3364 and 1223 is: (output = 35, expected = 35) True
# The shortest distance between 660 and 2432 is: (output = 19, expected = 19) True
# The shortest distance between 2552 and 1251 is: (output = 45, expected = 45) True
# The shortest distance between 3374 and 667 is: (output = 26, expected = 26) True
# The shortest distance between 1824 and 1016 is: (output = 34, expected = 34) True
# The shortest distance between 3926 and 3773 is: (output = 44, expected = 44) True
# The shortest distance between 3214 and 660 is: (output = 15, expected = 15) True
# The shortest distance between 133 and 2149 is: (output = 40, expected = 40) True
# The shortest distance between 1308 and 830 is: (output = 32, expected = 32) True
# The shortest distance between 3491 and 1729 is: (output = 32, expected = 32) True
# The shortest distance between 3096 and 2596 is: (output = 27, expected = 27) True
# The shortest distance between 63 and 1251 is: (output = 22, expected = 22) True
# The shortest distance between 1218 and 3286 is: (output = 43, expected = 43) True
# The shortest distance between 2897 and 1570 is: (output = 43, expected = 43) True
# The shortest distance between 3258 and 2044 is: (output = 31, expected = 31) True
# The shortest distance between 1490 and 3046 is: (output = 23, expected = 23) True
# The shortest distance between 1070 and 2947 is: (output = 43, expected = 43) True
# The shortest distance between 633 and 1100 is: (output = 27, expected = 27) True
# The shortest distance between 3331 and 1420 is: (output = 49, expected = 49) True
# The shortest distance between 580 and 2560 is: (output = 24, expected = 24) True
# The shortest distance between 2113 and 2803 is: (output = 28, expected = 28) True
# The shortest distance between 1796 and 3542 is: (output = 49, expected = 49) True
# The shortest distance between 1058 and 2833 is: (output = 23, expected = 23) True
# The shortest distance between 551 and 1322 is: (output = 18, expected = 18) True
# The shortest distance between 1270 and 832 is: (output = 29, expected = 29) True
# The shortest distance between 2 and 846 is: (output = 45, expected = 45) True
# The shortest distance between 2559 and 1034 is: (output = 23, expected = 23) True
# The shortest distance between 1723 and 2596 is: (output = 24, expected = 24) True
# The shortest distance between 3594 and 349 is: (output = 38, expected = 38) True
# The shortest distance between 1663 and 449 is: (output = 33, expected = 33) True
# The shortest distance between 604 and 1430 is: (output = 28, expected = 28) True
# The shortest distance between 3154 and 1174 is: (output = 37, expected = 37) True
# The shortest distance between 1200 and 3030 is: (output = 37, expected = 37) True
# The shortest distance between 753 and 2088 is: (output = 45, expected = 45) True
# The shortest distance between 1008 and 1293 is: (output = 52, expected = 52) True
# The shortest distance between 1022 and 1541 is: (output = 35, expected = 35) True
# The shortest distance between 1057 and 1870 is: (output = 37, expected = 37) True
# The shortest distance between 1851 and 555 is: (output = 34, expected = 34) True
# The shortest distance between 2526 and 23 is: (output = 35, expected = 35) True
# The shortest distance between 2496 and 3434 is: (output = 38, expected = 38) True
# The shortest distance between 2414 and 1203 is: (output = 40, expected = 40) True
# The shortest distance between 2909 and 634 is: (output = 27, expected = 27) True
# The shortest distance between 3688 and 920 is: (output = 22, expected = 22) True
# The shortest distance between 183 and 1738 is: (output = 46, expected = 46) True
# The shortest distance between 2076 and 2284 is: (output = 49, expected = 49) True
# The shortest distance between 112 and 1947 is: (output = 31, expected = 31) True
# The shortest distance between 2021 and 3930 is: (output = 45, expected = 45) True
# The shortest distance between 3369 and 1588 is: (output = 12, expected = 12) True
# The shortest distance between 3817 and 1320 is: (output = 21, expected = 21) True
# The shortest distance between 2026 and 1711 is: (output = 29, expected = 29) True
# The shortest distance between 1221 and 1094 is: (output = 37, expected = 37) True
# The shortest distance between 2467 and 2945 is: (output = 44, expected = 44) True
# The shortest distance between 2886 and 2894 is: (output = 33, expected = 33) True
# The shortest distance between 2787 and 2259 is: (output = 20, expected = 20) True
# The shortest distance between 62 and 3194 is: (output = 33, expected = 33) True
# The shortest distance between 3214 and 68 is: (output = 16, expected = 16) True
# The shortest distance between 324 and 1287 is: (output = 28, expected = 28) True
# The shortest distance between 2233 and 570 is: (output = 30, expected = 30) True
# The shortest distance between 3279 and 1647 is: (output = 26, expected = 26) True
# The shortest distance between 2061 and 3338 is: (output = 13, expected = 13) True
# The shortest distance between 2468 and 376 is: (output = 19, expected = 19) True
# The shortest distance between 1339 and 1306 is: (output = 20, expected = 20) True
# The shortest distance between 3878 and 2136 is: (output = 49, expected = 49) True
# The shortest distance between 3484 and 553 is: (output = 13, expected = 13) True
# The shortest distance between 2312 and 1550 is: (output = 47, expected = 47) True
# The shortest distance between 587 and 2067 is: (output = 18, expected = 18) True
# The shortest distance between 2313 and 1031 is: (output = 12, expected = 12) True
# The shortest distance between 1260 and 1241 is: (output = 10, expected = 10) True
# The shortest distance between 1613 and 2477 is: (output = 9, expected = 9) True
# The shortest distance between 2298 and 508 is: (output = 55, expected = 55) True
# The shortest distance between 1285 and 2040 is: (output = 47, expected = 47) True
# The shortest distance between 2660 and 2365 is: (output = 51, expected = 51) True
# The shortest distance between 3516 and 2592 is: (output = 35, expected = 35) True
# The shortest distance between 3775 and 1898 is: (output = 38, expected = 38) True
# The shortest distance between 3917 and 2104 is: (output = 46, expected = 46) True
# The shortest distance between 1912 and 1325 is: (output = 55, expected = 55) True
# The shortest distance between 366 and 1450 is: (output = 25, expected = 25) True
# The shortest distance between 1165 and 3156 is: (output = 38, expected = 38) True
# The shortest distance between 2502 and 3415 is: (output = 29, expected = 29) True
# The shortest distance between 132 and 2929 is: (output = 32, expected = 32) True
# The shortest distance between 1170 and 2211 is: (output = 50, expected = 50) True
# The shortest distance between 2770 and 3116 is: (output = 61, expected = 61) True
# The shortest distance between 1653 and 1472 is: (output = 37, expected = 37) True
# The shortest distance between 910 and 3265 is: (output = 26, expected = 26) True
# The shortest distance between 2962 and 650 is: (output = 37, expected = 37) True
# The shortest distance between 1816 and 2804 is: (output = 47, expected = 47) True
# The shortest distance between 3184 and 2860 is: (output = 43, expected = 43) True
# The shortest distance between 1802 and 2700 is: (output = 20, expected = 20) True
# The shortest distance between 805 and 1306 is: (output = 22, expected = 22) True
# The shortest distance between 3259 and 3425 is: (output = 38, expected = 38) True
# The shortest distance between 2934 and 3069 is: (output = 48, expected = 48) True
# The shortest distance between 2028 and 1699 is: (output = 30, expected = 30) True
# The shortest distance between 1989 and 2584 is: (output = 24, expected = 24) True
# The shortest distance between 2969 and 792 is: (output = 18, expected = 18) True
# The shortest distance between 3141 and 764 is: (output = 30, expected = 30) True
# The shortest distance between 3916 and 1548 is: (output = 47, expected = 47) True
# The shortest distance between 2975 and 672 is: (output = 49, expected = 49) True
# The shortest distance between 947 and 445 is: (output = 25, expected = 25) True
# The shortest distance between 1318 and 2372 is: (output = 58, expected = 58) True
# The shortest distance between 2065 and 1378 is: (output = 28, expected = 28) True
# The shortest distance between 3336 and 2100 is: (output = 13, expected = 13) True
# The shortest distance between 2460 and 3910 is: (output = 29, expected = 29) True
# The shortest distance between 3086 and 2906 is: (output = 52, expected = 52) True
# The shortest distance between 3009 and 750 is: (output = 16, expected = 16) True
# The shortest distance between 391 and 3970 is: (output = 49, expected = 49) True
# The shortest distance between 3701 and 1371 is: (output = 28, expected = 28) True
# The shortest distance between 3068 and 3476 is: (output = 63, expected = 63) True
# The shortest distance between 3433 and 2129 is: (output = 59, expected = 59) True
# The shortest distance between 206 and 2467 is: (output = 20, expected = 20) True
# The shortest distance between 1114 and 2330 is: (output = 34, expected = 34) True
# The shortest distance between 1480 and 846 is: (output = 8, expected = 8) True
# The shortest distance between 6 and 1650 is: (output = 16, expected = 16) True
# The shortest distance between 2309 and 874 is: (output = 57, expected = 57) True
# The shortest distance between 3965 and 3471 is: (output = 44, expected = 44) True
# The shortest distance between 1098 and 7 is: (output = 36, expected = 36) True
# The shortest distance between 99 and 1985 is: (output = 25, expected = 25) True
# The shortest distance between 877 and 1666 is: (output = 42, expected = 42) True
# The shortest distance between 627 and 611 is: (output = 8, expected = 8) True
# The shortest distance between 2208 and 3578 is: (output = 68, expected = 68) True
# The shortest distance between 502 and 1757 is: (output = 18, expected = 18) True
# The shortest distance between 3285 and 2392 is: (output = 36, expected = 36) True
# The shortest distance between 723 and 1292 is: (output = 48, expected = 48) True
# The shortest distance between 227 and 2516 is: (output = 33, expected = 33) True
# The shortest distance between 3208 and 1361 is: (output = 52, expected = 52) True
# The shortest distance between 1911 and 2425 is: (output = 63, expected = 63) True
# The shortest distance between 1648 and 2116 is: (output = 56, expected = 56) True
# The shortest distance between 1970 and 3752 is: (output = 49, expected = 49) True
# The shortest distance between 1764 and 2735 is: (output = 25, expected = 25) True
# The shortest distance between 3613 and 1228 is: (output = 30, expected = 30) True
# The shortest distance between 1879 and 1274 is: (output = 38, expected = 38) True
# The shortest distance between 21 and 3640 is: (output = 41, expected = 41) True
# The shortest distance between 773 and 23 is: (output = 20, expected = 20) True
# The shortest distance between 1727 and 1369 is: (output = 31, expected = 31) True
# The shortest distance between 3986 and 22 is: (output = 27, expected = 27) True
# Count of false outputs: 0
# Average query time: 0.00007320
